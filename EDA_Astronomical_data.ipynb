# %% [markdown]
# <a href="https://colab.research.google.com/github/Devacodes-dev/WinterArc-InternshipPrep/blob/main/EDA_Astronomical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS ON ASTRONOMICAL DATASET**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-2-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive"
# Out:
# '21CSC204J DAA LAB MANUAL (1) (1).gdoc'
# '21CSC204J DAA LAB MANUAL (1) (1).pdf'
# '21CSC204J DAA LAB MANUAL (1).gdoc'
# '21CSC204J DAA LAB MANUAL (1).pdf'
# '720225933-Daa-Elab-Daa-Elab-Answers-1 (1).gdoc'
# '720225933-Daa-Elab-Daa-Elab-Answers-1 (1).pdf'
# '720225933-Daa-Elab-Daa-Elab-Answers-1 (2).gdoc'
#  720225933-Daa-Elab-Daa-Elab-Answers-1.gdoc
#  720225933-Daa-Elab-Daa-Elab-Answers-1.pdf
# 'Aoop lab manual.gdoc'
#  Classroom
#  cleaned_star_data.xlsx
# 'Colab Notebooks'
# 'DAA elab answers (1).gdoc'
# 'DAA elab answers (1).pdf'
# 'DAA elab answers (2).gdoc'
# 'DAA elab answers (2).pdf'
# 'DAA elab answers (3).gdoc'
# 'DAA elab answers (3).pdf'
# 'DAA elab answers.gdoc'
# 'DAA elab answers.pdf'
# 'Devadharshini (datasets) '
# 'DS LAB MANUAL(R2021).gdoc'
# 'ELAB solutions (1).gdoc'
# 'ELAB solutions (1).pdf'
# 'ELAB solutions (2).gdoc'
# 'ELAB solutions (2).pdf'
# 'ELAB solutions (3).gdoc'
# 'ELAB solutions (3).pdf'
# 'ELAB solutions.gdoc'
# 'ELAB solutions.pdf'
# ...

# %%
df=pd.read_csv('cleaned_star_data.csv')
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
df.sample(10)     # to generate random sample of the data with n rows
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 87             10980           0.00074       0.00870                   11.19
# 71              3607           0.02200       0.38000                   10.12
# 2               2600           0.00030       0.10200                   18.70
# 136             3091           0.00810       0.24000                   11.43
# 175             3614      145000.00000    1553.00000                   -7.71
# 109            33421      352000.00000      67.00000                   -5.79
# 64              2935           0.00014       0.11600                   18.89
# 24             16500           0.01300       0.01400                   11.89
# 145             8924           0.00028       0.00879                   14.87
# 121             3531           0.00093       0.09760                   19.94
#
#      Star type  Star color Spectral Class
# 87           2  Blue-White              B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
# about the dataset
#
#
# 1.   It has 7 col
#
# *   temperature
# *   luminosity(l/lo- relative)
# *   radius(r/r0)
# *   abs magnitude
# *   star type (target column)
# *   star color(object)- categorical data
# *   spectral class(object)-categorical data
#
# 2.   star tye integer values
#
# *   0- brown dwarf
# *   1-red dwarf
# *   2-white dwarf
# *   3- main sequence
# *   4-super giant
# *   5-hypergiants
# to create HR diagram

# %%
folder_name='star_plots'
os.makedirs(folder_name,exist_ok=True)  # use to create a directory to store our visualization images
base_dir=f'/content/{folder_name}/'

# %% [markdown]
# 1) VISUALIZE THE COUNT OF STARS TYPES

# %%
df['Star type'].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# 2) customize(les make it pretty understanding) and save it

# %%
plt.figure(figsize=(5,5))
plt.title('Visualize star count per star type', color='purple')
ax=df['Star type'].value_counts().plot(kind="bar", color=['yellow','red','lightblue','pink','green','royalblue'])  # saved the plot in a variable
plt.style.use('Solarize_Light2')
ax.bar_label(ax.containers[0],color='purple') # display the count of each bar in the plot , color
plt.ylabel('number of stars', color='purple') # title for y axis and its color
plt.xlabel('star type',color='purple')        # title for x axis and its color
plt.yticks(color='magenta')                   #  give color to the intervals of y axis
plt.xticks(ticks=[0,1,2,3,4,5], labels=['Brown\nDwarf','Red\nDwarf','White\nDwarf' ,'Main\nSequence','Super\nGiant','Hyper\nGiant'], rotation=45,color='magenta')
plt.savefig(base_dir+'star_type.png')
plt.show()

# %%
print(plt.style.available)     # command to get all the style names available
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# 3) use seaborn to make the barplot and compare the outputs

# %%
# df['Star color'].value_counts()  - this prints the output with two columns: color and its respective count
#df['Star color'].value_counts().index  # this prints only the colors which the index
ax =sns.barplot(x=df['Star color'].value_counts().index , y=df['Star color'].value_counts(),
            palette='pastel6')
for container in ax.containers:
    ax.bar_label(container,color='brown')
plt.title("Visualize the count of each star color", color='brown', fontsize=15,weight='heavy')
plt.xticks(rotation=15,color='brown')
plt.xlabel('star color',color='brown')
plt.ylabel('star count per color',color='brown',fontsize=13)
plt.yticks(color='brown')
plt.savefig(base_dir+'star_color.png')
plt.show()
# Out:
# /tmp/ipython-input-11-2272271506.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax =sns.barplot(x=df['Star color'].value_counts().index , y=df['Star color'].value_counts(),

# %%
print(sns.palettes.SEABORN_PALETTES.keys())   # to list all the available palettes,for the abr colors
# Out:
# dict_keys(['deep', 'deep6', 'muted', 'muted6', 'pastel', 'pastel6', 'bright', 'bright6', 'dark', 'dark6', 'colorblind', 'colorblind6'])

# %% [markdown]
# 3)VISUALIZE OUTLIERS
#
# *   box plots
# *   sub plots

# %%
 df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %% [markdown]
# VISUALIZE OUTLIERS

# %%
plt.figure(figsize=(20,8))
plt.style.use('default')
plt.suptitle('Visualizing the outliers in numeric features using star type', color='black', fontsize=15, weight='bold')

for i in range(4):
  plt.subplot(1,4,i+1)
  sns.boxplot(x=df['Star type'],y=df.iloc[:,i],palette='pastel6')
  plt.ylabel('')
  plt.title(df.columns[i], color='red')

plt.savefig(base_dir+'boxplot_star_type.png')
plt.show()
# Out:
# /tmp/ipython-input-44-3036472559.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Star type'],y=df.iloc[:,i],palette='pastel6')
# /tmp/ipython-input-44-3036472559.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Star type'],y=df.iloc[:,i],palette='pastel6')
# /tmp/ipython-input-44-3036472559.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Star type'],y=df.iloc[:,i],palette='pastel6')
# /tmp/ipython-input-44-3036472559.py:7: FutureWarning:
#
# ...

# %% [markdown]
# 4) line plot
# to visulaize patterns in each of numeric features in data

# %%
def line_subplot(df,start,i):
  plt.subplot(4,1,i+1)
  plt.plot(df.iloc[:,i], color=colors[i])
  plt.title(df.columns[i], color='brown')

# %%
plt.figure(figsize=(10,8))
colors=['royalblue','gold','lime','magenta']
plt.suptitle('Visualizing the Distribution of Numeric Features\n', fontsize=15, weight='bold')  # title of the subplot is called suptitle
for i in range(4):
  line_subplot(df,4,i)

plt.tight_layout() # adjusts the plot according to space
plt.savefig(base_dir+'lineplot_patterns.png')
plt.show()



  #plt.subplot(4,1,i+1)     #creates subplot that has 4 rows and 1 column
  #plt.plot(df.iloc[:,i], color=colors[i])   # give colors to each line  sub plot
  #plt.title(df.columns[i], color='brown')   # the ylabel is column name right? so that becomes the column name of the subplot
